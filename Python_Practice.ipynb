# %% [markdown]
# <a href="https://colab.research.google.com/github/HunaizaFaisal/Python-Projects/blob/main/Python_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic Level
#Create a list called fruits containing:
fruits=["Apple","Mango","Banana","Pear"]
print (fruits)
# Out:
# ['Apple', 'Mango', 'Banana', 'Pear']

# %%
Print:

#The first student
#The third student
#The last student
fruits=["Apple","Mango","Banana","Pear"]
print (fruits[1])
# Out:
#   File "/tmp/ipykernel_4432/1715373547.py", line 1
#     Print:
#           ^
# SyntaxError: invalid syntax
